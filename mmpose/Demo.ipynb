# %%
import argparse
import json
import os
 
import cv2
import numpy as np

# %%
# Step 1: Define the path to the JSON file
json_file_path = '/data/muxiangyu/TryonDatasets/datasets/mmPose/91-BAOunZBS_json/006.json'

# Step 2: Read the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Step 3: Print the data to verify
print(data[0]['keypoints']) # len(pose) = 133

wholePoseList = data[0]['keypoints']


poseList = []
for i in range(17):
    poseList.append(wholePoseList[i])
feetList = []
for i in range(17,23):
    feetList.append(wholePoseList[i])
faceList = []
for i in range(23,91):
    faceList.append(wholePoseList[i])
handList = []
for i in range(91,133):
    handList.append(wholePoseList[i])
# Out:
# [[126.9698486328125, 51.78755187988281], [135.1373291015625, 43.62007141113281], [118.8023681640625, 43.62007141113281], [146.80516052246094, 48.287200927734375], [108.30132293701172, 49.453983306884766], [170.1408233642578, 104.29277801513672], [87.29923248291016, 105.45956420898438], [180.64186096191406, 171.9661865234375], [81.46531677246094, 174.29974365234375], [181.8086395263672, 236.1392364501953], [77.96497344970703, 238.47280883789062], [153.8058624267578, 238.47280883789062], [103.63419342041016, 238.47280883789062], [147.97193908691406, 343.4832763671875], [108.30132293701172, 343.4832763671875], [137.4709014892578, 444.9933776855469], [114.13523864746094, 444.9933776855469], [135.1373291015625, 474.1629333496094], [149.13873291015625, 471.8293762207031], [132.80377197265625, 455.4944152832031], [114.13523864746094, 475.3297119140625], [101.30062866210938, 470.66259765625], [118.8023681640625, 455.4944152832031], [108.30132293701172, 44.7868537902832], [108.30132293701172,
# ...

# %%
width, height = 256,512

black_image = np.zeros((height, width, 3), np.uint8)

for pose in poseList:
    black_image = cv2.circle(black_image, (int(pose[0]), int(pose[1])), 4, (0, 255, 0), -1)

black_image = cv2.circle(black_image, (int(poseList[0][0]), int(poseList[0][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[1][0]), int(poseList[1][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[2][0]), int(poseList[2][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[3][0]), int(poseList[3][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[4][0]), int(poseList[4][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[5][0]), int(poseList[5][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[6][0]), int(poseList[6][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[7][0]), int(poseList[7][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[8][0]), int(poseList[8][1])), 5, (0, 255, 0), -1)
black_image = cv2.circle(black_image, (int(poseList[9][0]), int(poseList[9][1])), 5, (0, 255, 0), -1)


cv2.imwrite('test.jpg', black_image)
# Out:
# True
